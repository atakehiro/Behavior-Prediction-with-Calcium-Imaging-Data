# %%
import os
import tensorflow as tf
import logging
import warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.utils import np_utils
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense
from keras.layers import LSTM, GRU, SimpleRNN, ConvLSTM2D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from scipy import io
# Out:
# Using TensorFlow backend.

# %%
set_num = 64
matdata = io.loadmat('data/signals.mat')
signals = numpy.zeros((50, 18000*set_num))
for i in range(set_num):
    signals[:,i*18000:(i+1)*18000]  = matdata['s'+str(i+1)]
plt.plot(signals.transpose())
plt.show()
print(signals.shape)
# Out:
# (50, 1152000)

# %%
matdata = io.loadmat('data/behaviors.mat')
behavis = numpy.zeros((1, 18000*set_num))
for i in range(set_num):
    behavis[:,i*18000:(i+1)*18000]  = matdata['b'+str(i+1)]
plt.plot(behavis.transpose())
plt.show()
print(behavis.shape)
# Out:
# (1, 1152000)

# %%
dataset = numpy.hstack([signals.transpose().astype('float32'), behavis.transpose().astype('float32')])
print(dataset.shape)
# Out:
# (1152000, 51)

# %%
# # normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[0.5243208 , 0.4756588 , 0.52478135, ..., 0.52060586, 0.45601395,
#         1.        ],
#        [0.5294922 , 0.4874594 , 0.54577094, ..., 0.550915  , 0.44861886,
#         1.        ],
#        [0.53681123, 0.4916609 , 0.5472613 , ..., 0.5696357 , 0.44246095,
#         1.        ],
#        ...,
#        [0.38074595, 0.3246355 , 0.42398232, ..., 0.33834928, 0.34063563,
#         0.        ],
#        [0.38334918, 0.31798124, 0.40275556, ..., 0.2984794 , 0.3288611 ,
#         0.        ],
#        [0.39405167, 0.34444982, 0.4290545 , ..., 0.3360081 , 0.3545482 ,
#         0.        ]], dtype=float32)

# %%
# split into train and test sets
train_size = int(len(dataset) * 32/set_num)
valid_size = int(len(dataset) * 16/set_num)
test_size = len(dataset) - (train_size + valid_size)
train = dataset[0:train_size,:]
valid = dataset[train_size:(train_size + valid_size),:]
test = dataset[(train_size + valid_size):len(dataset),:]
print(len(train),len(valid), len(test))
# Out:
# 576000 288000 288000

# %%
# convert an array of values into a dataset matrix
def create_dataset_back(dataset, look_frame):
    dataX, dataY = [], []
    for i in range(look_frame,len(dataset)):
        xset = []
        for j in range(dataset.shape[1]-1):
            a = dataset[(i-look_frame):i, j]
            xset.append(a)
        dataY.append(dataset[i, -1])      
        dataX.append(xset)
    return numpy.array(dataX), numpy.array(dataY)

look_frame = 10 #前ｎフレームまで読み込んで入力とする
trainX, trainY = create_dataset_back(train, look_frame)
print(trainX.shape)
print(trainY.shape)
validX, validY = create_dataset_back(valid, look_frame)
print(validX.shape)
print(validY.shape)
testX, testY = create_dataset_back(test, look_frame)
print(testX.shape)
print(testY.shape)
# Out:
# (575990, 50, 10)
# (575990,)
# (287990, 50, 10)
# (287990,)
# (287990, 50, 10)
# (287990,)

# %%
# transpose input
input_train = trainX.transpose(0,2,1)
input_valid = validX.transpose(0,2,1)
input_test = testX.transpose(0,2,1)
print(input_train.shape)
print(input_valid.shape)
print(input_test.shape)
# Out:
# (575990, 10, 50)
# (287990, 10, 50)
# (287990, 10, 50)

# %%
# callback設定
modelCheckpoint = ModelCheckpoint(filepath = 'best_mmodel.h5',
                                  monitor='val_loss',
                                  verbose=1,
                                  save_best_only=True,
                                  save_weights_only=False,
                                  mode='min',
                                  period=1)

# %%
# create and fit the LSTM network
output_dim = 32 #modelの複雑さに合わせて決める
model = Sequential()
model.add(LSTM(output_dim, input_shape=(look_frame, trainX.shape[1])))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x=input_train, y=trainY, validation_data=(input_valid, validY), epochs=100, batch_size=256, verbose=2, callbacks=[modelCheckpoint])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                10624
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,657
# Trainable params: 10,657
# Non-trainable params: 0
# _________________________________________________________________
# Train on 575990 samples, validate on 287990 samples
# Epoch 1/100
#  - 15s - loss: 0.4860 - accuracy: 0.7755 - val_loss: 0.4653 - val_accuracy: 0.7877
#
# Epoch 00001: val_loss improved from inf to 0.46529, saving model to best_mmodel.h5
# Epoch 2/100
#  - 15s - loss: 0.4245 - accuracy: 0.8135 - val_loss: 0.4436 - val_accuracy: 0.8044
#
# Epoch 00002: val_loss improved from 0.46529 to 0.44357, saving model to best_mmodel.h5
# Epoch 3/100
#  - 15s - loss: 0.3953 - accuracy: 0.8293 - val_loss: 0.4361 - val_accuracy: 0.8081
#
# Epoch 00003: val_loss improved from 0.44357 to 0.43609, saving model to best_mmodel.h5
# Epoch 4/100
#  - 15s - loss: 0.3773 - accuracy: 0.8386 - val_loss: 0.3991 - val_accuracy: 0.8246
#
# Epoch 00004: val_loss improved from 0.43609 to 0.39908, saving model to best_mmodel.h5
# Epoch 5/100
#  - 16s - loss: 0.3589 - accuracy: 0.8482 - val_loss: 0.4057 - val_accuracy: 0.8235
#
# Epoch 00005: val_loss did not improve from 0.39908
# Epoch 6/100
#  - 15s - loss: 0.3452 - accuracy: 0.8544 - val_loss: 0.3954 - val_accuracy: 0.8299
#
# Epoch 00006: val_loss improved from 0.39908 to 0.39537, saving model to best_mmodel.h5
# Epoch 7/100
#  - 15s - loss: 0.3322 - accuracy: 0.8617 - val_loss: 0.3663 - val_accuracy: 0.8446
#
# Epoch 00007: val_loss improved from 0.39537 to 0.36631, saving model to best_mmodel.h5
# Epoch 8/100
#  - 15s - loss: 0.3221 - accuracy: 0.8668 - val_loss: 0.3760 - val_accuracy: 0.8403
#
# Epoch 00008: val_loss did not improve from 0.36631
# Epoch 9/100
#  - 15s - loss: 0.3131 - accuracy: 0.8716 - val_loss: 0.3604 - val_accuracy: 0.8483
#
# Epoch 00009: val_loss improved from 0.36631 to 0.36041, saving model to best_mmodel.h5
# Epoch 10/100
#  - 15s - loss: 0.3056 - accuracy: 0.8751 - val_loss: 0.3534 - val_accuracy: 0.8541
#
# Epoch 00010: val_loss improved from 0.36041 to 0.35335, saving model to best_mmodel.h5
# Epoch 11/100
#  - 15s - loss: 0.3020 - accuracy: 0.8765 - val_loss: 0.3639 - val_accuracy: 0.8463
#
# Epoch 00011: val_loss did not improve from 0.35335
# Epoch 12/100
#  - 15s - loss: 0.2957 - accuracy: 0.8795 - val_loss: 0.3535 - val_accuracy: 0.8538
#
# Epoch 00012: val_loss did not improve from 0.35335
# Epoch 13/100
#  - 14s - loss: 0.2916 - accuracy: 0.8815 - val_loss: 0.4254 - val_accuracy: 0.8214
#
# Epoch 00013: val_loss did not improve from 0.35335
# Epoch 14/100
#  - 14s - loss: 0.2867 - accuracy: 0.8836 - val_loss: 0.3528 - val_accuracy: 0.8544
#
# Epoch 00014: val_loss improved from 0.35335 to 0.35283, saving model to best_mmodel.h5
# Epoch 15/100
#  - 14s - loss: 0.2843 - accuracy: 0.8848 - val_loss: 0.3397 - val_accuracy: 0.8606
#
# Epoch 00015: val_loss improved from 0.35283 to 0.33969, saving model to best_mmodel.h5
# Epoch 16/100
#  - 14s - loss: 0.2798 - accuracy: 0.8867 - val_loss: 0.3593 - val_accuracy: 0.8526
#
# Epoch 00016: val_loss did not improve from 0.33969
# Epoch 17/100
#  - 14s - loss: 0.2763 - accuracy: 0.8880 - val_loss: 0.3411 - val_accuracy: 0.8598
#
# Epoch 00017: val_loss did not improve from 0.33969
# Epoch 18/100
#  - 15s - loss: 0.2742 - accuracy: 0.8891 - val_loss: 0.3468 - val_accuracy: 0.8586
#
# Epoch 00018: val_loss did not improve from 0.33969
# Epoch 19/100
#  - 14s - loss: 0.2711 - accuracy: 0.8904 - val_loss: 0.3395 - val_accuracy: 0.8632
#
# Epoch 00019: val_loss improved from 0.33969 to 0.33950, saving model to best_mmodel.h5
# Epoch 20/100
#  - 15s - loss: 0.2681 - accuracy: 0.8917 - val_loss: 0.3394 - val_accuracy: 0.8598
#
# Epoch 00020: val_loss improved from 0.33950 to 0.33938, saving model to best_mmodel.h5
# Epoch 21/100
#  - 14s - loss: 0.2657 - accuracy: 0.8929 - val_loss: 0.3316 - val_accuracy: 0.8653
#
# Epoch 00021: val_loss improved from 0.33938 to 0.33162, saving model to best_mmodel.h5
# Epoch 22/100
#  - 14s - loss: 0.2639 - accuracy: 0.8941 - val_loss: 0.3223 - val_accuracy: 0.8681
#
# Epoch 00022: val_loss improved from 0.33162 to 0.32226, saving model to best_mmodel.h5
# Epoch 23/100
#  - 14s - loss: 0.2607 - accuracy: 0.8952 - val_loss: 0.3202 - val_accuracy: 0.8700
#
# Epoch 00023: val_loss improved from 0.32226 to 0.32022, saving model to best_mmodel.h5
# Epoch 24/100
#  - 14s - loss: 0.2594 - accuracy: 0.8957 - val_loss: 0.3188 - val_accuracy: 0.8704
#
# Epoch 00024: val_loss improved from 0.32022 to 0.31878, saving model to best_mmodel.h5
# Epoch 25/100
#  - 14s - loss: 0.2572 - accuracy: 0.8967 - val_loss: 0.3324 - val_accuracy: 0.8653
#
# Epoch 00025: val_loss did not improve from 0.31878
# Epoch 26/100
#  - 14s - loss: 0.2554 - accuracy: 0.8976 - val_loss: 0.3130 - val_accuracy: 0.8742
#
# Epoch 00026: val_loss improved from 0.31878 to 0.31304, saving model to best_mmodel.h5
# Epoch 27/100
#  - 14s - loss: 0.2507 - accuracy: 0.8998 - val_loss: 0.3098 - val_accuracy: 0.8759
#
# Epoch 00027: val_loss improved from 0.31304 to 0.30976, saving model to best_mmodel.h5
# Epoch 28/100
#  - 15s - loss: 0.2495 - accuracy: 0.9001 - val_loss: 0.3002 - val_accuracy: 0.8777
#
# Epoch 00028: val_loss improved from 0.30976 to 0.30017, saving model to best_mmodel.h5
# Epoch 29/100
#  - 14s - loss: 0.2456 - accuracy: 0.9020 - val_loss: 0.3084 - val_accuracy: 0.8749
#
# Epoch 00029: val_loss did not improve from 0.30017
# Epoch 30/100
#  - 15s - loss: 0.2428 - accuracy: 0.9029 - val_loss: 0.2939 - val_accuracy: 0.8819
#
# Epoch 00030: val_loss improved from 0.30017 to 0.29394, saving model to best_mmodel.h5
# Epoch 31/100
#  - 14s - loss: 0.2393 - accuracy: 0.9046 - val_loss: 0.2885 - val_accuracy: 0.8851
#
# Epoch 00031: val_loss improved from 0.29394 to 0.28845, saving model to best_mmodel.h5
# Epoch 32/100
#  - 14s - loss: 0.2364 - accuracy: 0.9058 - val_loss: 0.2845 - val_accuracy: 0.8875
#
# Epoch 00032: val_loss improved from 0.28845 to 0.28448, saving model to best_mmodel.h5
# Epoch 33/100
#  - 14s - loss: 0.2310 - accuracy: 0.9084 - val_loss: 0.2775 - val_accuracy: 0.8885
#
# Epoch 00033: val_loss improved from 0.28448 to 0.27752, saving model to best_mmodel.h5
# Epoch 34/100
#  - 14s - loss: 0.2255 - accuracy: 0.9109 - val_loss: 0.2865 - val_accuracy: 0.8921
#
# Epoch 00034: val_loss did not improve from 0.27752
# Epoch 35/100
#  - 14s - loss: 0.2193 - accuracy: 0.9136 - val_loss: 0.2530 - val_accuracy: 0.9033
#
# Epoch 00035: val_loss improved from 0.27752 to 0.25298, saving model to best_mmodel.h5
# Epoch 36/100
#  - 14s - loss: 0.2119 - accuracy: 0.9169 - val_loss: 0.2391 - val_accuracy: 0.9121
#
# Epoch 00036: val_loss improved from 0.25298 to 0.23909, saving model to best_mmodel.h5
# Epoch 37/100
#  - 14s - loss: 0.2063 - accuracy: 0.9197 - val_loss: 0.2601 - val_accuracy: 0.8950
#
# Epoch 00037: val_loss did not improve from 0.23909
# Epoch 38/100
#  - 14s - loss: 0.2021 - accuracy: 0.9219 - val_loss: 0.2377 - val_accuracy: 0.9122
#
# Epoch 00038: val_loss improved from 0.23909 to 0.23770, saving model to best_mmodel.h5
# Epoch 39/100
#  - 14s - loss: 0.1986 - accuracy: 0.9232 - val_loss: 0.2269 - val_accuracy: 0.9162
#
# Epoch 00039: val_loss improved from 0.23770 to 0.22686, saving model to best_mmodel.h5
# Epoch 40/100
#  - 14s - loss: 0.1957 - accuracy: 0.9242 - val_loss: 0.2263 - val_accuracy: 0.9168
#
# Epoch 00040: val_loss improved from 0.22686 to 0.22630, saving model to best_mmodel.h5
# Epoch 41/100
#  - 14s - loss: 0.1933 - accuracy: 0.9252 - val_loss: 0.2209 - val_accuracy: 0.9184
#
# Epoch 00041: val_loss improved from 0.22630 to 0.22094, saving model to best_mmodel.h5
# Epoch 42/100
#  - 16s - loss: 0.1910 - accuracy: 0.9267 - val_loss: 0.2183 - val_accuracy: 0.9181
#
# Epoch 00042: val_loss improved from 0.22094 to 0.21826, saving model to best_mmodel.h5
# Epoch 43/100
#  - 14s - loss: 0.1887 - accuracy: 0.9274 - val_loss: 0.2089 - val_accuracy: 0.9224
#
# Epoch 00043: val_loss improved from 0.21826 to 0.20891, saving model to best_mmodel.h5
# Epoch 44/100
#  - 14s - loss: 0.1871 - accuracy: 0.9277 - val_loss: 0.2110 - val_accuracy: 0.9216
# Epoch 00044: val_loss did not improve from 0.20891
# Epoch 45/100
#  - 14s - loss: 0.1848 - accuracy: 0.9288 - val_loss: 0.2247 - val_accuracy: 0.9205
#
# Epoch 00045: val_loss did not improve from 0.20891
# Epoch 46/100
#  - 14s - loss: 0.1841 - accuracy: 0.9290 - val_loss: 0.2143 - val_accuracy: 0.9208
#
# Epoch 00046: val_loss did not improve from 0.20891
# Epoch 47/100
#  - 14s - loss: 0.1825 - accuracy: 0.9297 - val_loss: 0.2140 - val_accuracy: 0.9220
#
# Epoch 00047: val_loss did not improve from 0.20891
# Epoch 48/100
#  - 14s - loss: 0.1819 - accuracy: 0.9297 - val_loss: 0.2087 - val_accuracy: 0.9243
#
# Epoch 00048: val_loss improved from 0.20891 to 0.20874, saving model to best_mmodel.h5
# Epoch 49/100
#  - 14s - loss: 0.1804 - accuracy: 0.9303 - val_loss: 0.2148 - val_accuracy: 0.9237
#
# Epoch 00049: val_loss did not improve from 0.20874
# Epoch 50/100
#  - 14s - loss: 0.1791 - accuracy: 0.9311 - val_loss: 0.2068 - val_accuracy: 0.9246
#
# Epoch 00050: val_loss improved from 0.20874 to 0.20678, saving model to best_mmodel.h5
# Epoch 51/100
#  - 14s - loss: 0.1786 - accuracy: 0.9316 - val_loss: 0.2053 - val_accuracy: 0.9248
#
# Epoch 00051: val_loss improved from 0.20678 to 0.20529, saving model to best_mmodel.h5
# Epoch 52/100
#  - 14s - loss: 0.1771 - accuracy: 0.9320 - val_loss: 0.2066 - val_accuracy: 0.9255
#
# Epoch 00052: val_loss did not improve from 0.20529
# Epoch 53/100
#  - 14s - loss: 0.1764 - accuracy: 0.9321 - val_loss: 0.2028 - val_accuracy: 0.9254
#
# Epoch 00053: val_loss improved from 0.20529 to 0.20275, saving model to best_mmodel.h5
# Epoch 54/100
#  - 14s - loss: 0.1756 - accuracy: 0.9324 - val_loss: 0.2045 - val_accuracy: 0.9252
#
# Epoch 00054: val_loss did not improve from 0.20275
# Epoch 55/100
#  - 14s - loss: 0.1740 - accuracy: 0.9332 - val_loss: 0.2074 - val_accuracy: 0.9249
#
# Epoch 00055: val_loss did not improve from 0.20275
# Epoch 56/100
#  - 14s - loss: 0.1740 - accuracy: 0.9330 - val_loss: 0.2002 - val_accuracy: 0.9274
#
# Epoch 00056: val_loss improved from 0.20275 to 0.20023, saving model to best_mmodel.h5
# Epoch 57/100
#  - 14s - loss: 0.1725 - accuracy: 0.9338 - val_loss: 0.2142 - val_accuracy: 0.9209
#
# Epoch 00057: val_loss did not improve from 0.20023
# Epoch 58/100
#  - 14s - loss: 0.1722 - accuracy: 0.9341 - val_loss: 0.1980 - val_accuracy: 0.9276
#
# Epoch 00058: val_loss improved from 0.20023 to 0.19801, saving model to best_mmodel.h5
# Epoch 59/100
#  - 14s - loss: 0.1716 - accuracy: 0.9340 - val_loss: 0.2137 - val_accuracy: 0.9192
#
# Epoch 00059: val_loss did not improve from 0.19801
# Epoch 60/100
#  - 14s - loss: 0.1703 - accuracy: 0.9345 - val_loss: 0.2026 - val_accuracy: 0.9266
#
# Epoch 00060: val_loss did not improve from 0.19801
# Epoch 61/100
#  - 14s - loss: 0.1700 - accuracy: 0.9350 - val_loss: 0.2032 - val_accuracy: 0.9253
#
# Epoch 00061: val_loss did not improve from 0.19801
# Epoch 62/100
#  - 14s - loss: 0.1691 - accuracy: 0.9352 - val_loss: 0.2042 - val_accuracy: 0.9263
#
# Epoch 00062: val_loss did not improve from 0.19801
# Epoch 63/100
#  - 14s - loss: 0.1680 - accuracy: 0.9357 - val_loss: 0.1924 - val_accuracy: 0.9290
#
# Epoch 00063: val_loss improved from 0.19801 to 0.19242, saving model to best_mmodel.h5
# Epoch 64/100
#  - 14s - loss: 0.1672 - accuracy: 0.9360 - val_loss: 0.1964 - val_accuracy: 0.9288
#
# Epoch 00064: val_loss did not improve from 0.19242
# Epoch 65/100
#  - 14s - loss: 0.1668 - accuracy: 0.9362 - val_loss: 0.1956 - val_accuracy: 0.9301
#
# Epoch 00065: val_loss did not improve from 0.19242
# Epoch 66/100
#  - 14s - loss: 0.1659 - accuracy: 0.9365 - val_loss: 0.2032 - val_accuracy: 0.9246
#
# Epoch 00066: val_loss did not improve from 0.19242
# Epoch 67/100
#  - 14s - loss: 0.1649 - accuracy: 0.9370 - val_loss: 0.2020 - val_accuracy: 0.9268
#
# Epoch 00067: val_loss did not improve from 0.19242
# Epoch 68/100
#  - 14s - loss: 0.1640 - accuracy: 0.9373 - val_loss: 0.1947 - val_accuracy: 0.9299
#
# Epoch 00068: val_loss did not improve from 0.19242
# Epoch 69/100
#  - 15s - loss: 0.1633 - accuracy: 0.9377 - val_loss: 0.1995 - val_accuracy: 0.9282
#
# Epoch 00069: val_loss did not improve from 0.19242
# Epoch 70/100
#  - 14s - loss: 0.1626 - accuracy: 0.9378 - val_loss: 0.1976 - val_accuracy: 0.9283
#
# Epoch 00070: val_loss did not improve from 0.19242
# Epoch 71/100
#  - 14s - loss: 0.1626 - accuracy: 0.9382 - val_loss: 0.1978 - val_accuracy: 0.9281
#
# Epoch 00071: val_loss did not improve from 0.19242
# Epoch 72/100
#  - 14s - loss: 0.1617 - accuracy: 0.9384 - val_loss: 0.1975 - val_accuracy: 0.9292
#
# Epoch 00072: val_loss did not improve from 0.19242
# Epoch 73/100
#  - 14s - loss: 0.1608 - accuracy: 0.9387 - val_loss: 0.2014 - val_accuracy: 0.9254
#
# Epoch 00073: val_loss did not improve from 0.19242
# Epoch 74/100
#  - 14s - loss: 0.1603 - accuracy: 0.9389 - val_loss: 0.1999 - val_accuracy: 0.9294
#
# Epoch 00074: val_loss did not improve from 0.19242
# Epoch 75/100
#  - 14s - loss: 0.1600 - accuracy: 0.9390 - val_loss: 0.1943 - val_accuracy: 0.9295
#
# Epoch 00075: val_loss did not improve from 0.19242
# Epoch 76/100
#  - 14s - loss: 0.1596 - accuracy: 0.9391 - val_loss: 0.1922 - val_accuracy: 0.9306
#
# Epoch 00076: val_loss improved from 0.19242 to 0.19223, saving model to best_mmodel.h5
# Epoch 77/100
#  - 14s - loss: 0.1589 - accuracy: 0.9394 - val_loss: 0.1910 - val_accuracy: 0.9313
#
# Epoch 00077: val_loss improved from 0.19223 to 0.19095, saving model to best_mmodel.h5
# Epoch 78/100
#  - 14s - loss: 0.1582 - accuracy: 0.9399 - val_loss: 0.1984 - val_accuracy: 0.9298
#
# Epoch 00078: val_loss did not improve from 0.19095
# Epoch 79/100
#  - 14s - loss: 0.1579 - accuracy: 0.9399 - val_loss: 0.1926 - val_accuracy: 0.9303
#
# Epoch 00079: val_loss did not improve from 0.19095
# Epoch 80/100
#  - 14s - loss: 0.1579 - accuracy: 0.9399 - val_loss: 0.2003 - val_accuracy: 0.9286
#
# Epoch 00080: val_loss did not improve from 0.19095
# Epoch 81/100
#  - 14s - loss: 0.1577 - accuracy: 0.9400 - val_loss: 0.1917 - val_accuracy: 0.9309
#
# Epoch 00081: val_loss did not improve from 0.19095
# Epoch 82/100
#  - 14s - loss: 0.1571 - accuracy: 0.9402 - val_loss: 0.1970 - val_accuracy: 0.9311
#
# Epoch 00082: val_loss did not improve from 0.19095
# Epoch 83/100
#  - 14s - loss: 0.1566 - accuracy: 0.9407 - val_loss: 0.2035 - val_accuracy: 0.9279
#
# Epoch 00083: val_loss did not improve from 0.19095
# Epoch 84/100
#  - 14s - loss: 0.1559 - accuracy: 0.9405 - val_loss: 0.1969 - val_accuracy: 0.9283
#
# Epoch 00084: val_loss did not improve from 0.19095
# Epoch 85/100
#  - 14s - loss: 0.1558 - accuracy: 0.9409 - val_loss: 0.2021 - val_accuracy: 0.9301
#
# Epoch 00085: val_loss did not improve from 0.19095
# Epoch 86/100
#  - 14s - loss: 0.1557 - accuracy: 0.9411 - val_loss: 0.1911 - val_accuracy: 0.9307
#
# Epoch 00086: val_loss did not improve from 0.19095
# Epoch 87/100
#  - 14s - loss: 0.1548 - accuracy: 0.9413 - val_loss: 0.1950 - val_accuracy: 0.9299
#
# Epoch 00087: val_loss did not improve from 0.19095
# Epoch 88/100
#  - 14s - loss: 0.1545 - accuracy: 0.9413 - val_loss: 0.1965 - val_accuracy: 0.9294
#
# Epoch 00088: val_loss did not improve from 0.19095
# Epoch 89/100
#  - 14s - loss: 0.1545 - accuracy: 0.9413 - val_loss: 0.1951 - val_accuracy: 0.9296
#
# Epoch 00089: val_loss did not improve from 0.19095
# Epoch 90/100
#  - 14s - loss: 0.1542 - accuracy: 0.9415 - val_loss: 0.1916 - val_accuracy: 0.9318
#
# Epoch 00090: val_loss did not improve from 0.19095
# Epoch 91/100
#  - 14s - loss: 0.1538 - accuracy: 0.9414 - val_loss: 0.2099 - val_accuracy: 0.9265
#
# Epoch 00091: val_loss did not improve from 0.19095
# Epoch 92/100
#  - 14s - loss: 0.1535 - accuracy: 0.9416 - val_loss: 0.1981 - val_accuracy: 0.9286
#
# Epoch 00092: val_loss did not improve from 0.19095
# Epoch 93/100
#  - 14s - loss: 0.1534 - accuracy: 0.9416 - val_loss: 0.2023 - val_accuracy: 0.9286
#
# Epoch 00093: val_loss did not improve from 0.19095
# Epoch 94/100
#  - 14s - loss: 0.1530 - accuracy: 0.9419 - val_loss: 0.1944 - val_accuracy: 0.9302
#
# Epoch 00094: val_loss did not improve from 0.19095
# Epoch 95/100
#  - 14s - loss: 0.1520 - accuracy: 0.9424 - val_loss: 0.2045 - val_accuracy: 0.9283
#
# Epoch 00095: val_loss did not improve from 0.19095
# Epoch 96/100
#  - 14s - loss: 0.1525 - accuracy: 0.9424 - val_loss: 0.2002 - val_accuracy: 0.9281
#
# Epoch 00096: val_loss did not improve from 0.19095
# Epoch 97/100
#  - 14s - loss: 0.1520 - accuracy: 0.9425 - val_loss: 0.1950 - val_accuracy: 0.9290
#
# Epoch 00097: val_loss did not improve from 0.19095
# Epoch 98/100
#  - 14s - loss: 0.1519 - accuracy: 0.9423 - val_loss: 0.1962 - val_accuracy: 0.9305
#
# Epoch 00098: val_loss did not improve from 0.19095
# Epoch 99/100
#  - 15s - loss: 0.1519 - accuracy: 0.9423 - val_loss: 0.1947 - val_accuracy: 0.9298
#
# Epoch 00099: val_loss did not improve from 0.19095
# Epoch 100/100
#  - 14s - loss: 0.1512 - accuracy: 0.9427 - val_loss: 0.1978 - val_accuracy: 0.9277
#
# Epoch 00100: val_loss did not improve from 0.19095

# %%
# plot
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %%
# Predict
model = load_model('best_mmodel.h5')
trainPredict = model.predict(input_train)
validPredict = model.predict(input_valid)
testPredict = model.predict(input_test)

# %%
# make predictions
pad_col = numpy.zeros(dataset.shape[1]-1)
def pad_array(val):
    return numpy.array([numpy.insert(pad_col, dataset.shape[1]-1, x) for x in val])

trainPredict1 = scaler.inverse_transform(pad_array(trainPredict))
trainY1 = scaler.inverse_transform(pad_array(trainY))

validPredict1 = scaler.inverse_transform(pad_array(validPredict))
validY1 = scaler.inverse_transform(pad_array(validY))

testPredict1 = scaler.inverse_transform(pad_array(testPredict))
testY1 = scaler.inverse_transform(pad_array(testY))

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY1[:,dataset.shape[1]-1], trainPredict1[:,dataset.shape[1]-1]))
print('Train Score: %.2f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY1[:,dataset.shape[1]-1], validPredict1[:,dataset.shape[1]-1]))
print('Valid Score: %.2f RMSE' % (validScore))
testScore = math.sqrt(mean_squared_error(testY1[:,dataset.shape[1]-1], testPredict1[:,dataset.shape[1]-1]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.21 RMSE
# Valid Score: 0.23 RMSE
# Test Score: 0.26 RMSE

# %%
# plot baseline and predictions
plt.plot(trainPredict1[:,dataset.shape[1]-1], label="prediction")
plt.plot(trainY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("training session")
plt.legend()
plt.show()
plt.plot(validPredict1[:,dataset.shape[1]-1], label="prediction")
plt.plot(validY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("valid session")
plt.legend()
plt.show()
plt.plot(testPredict1[:,dataset.shape[1]-1], label="prediction")
plt.plot(testY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("test session")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10.0, 5.0))
plt.plot(testPredict1[:,dataset.shape[1]-1])
plt.title("test prediction")
plt.show()
plt.figure(figsize=(10.0, 5.0))
plt.plot(testY1[:,dataset.shape[1]-1])
plt.title("test ground truth")
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc, roc_auc_score

y_test, y_pred = trainY1[:,dataset.shape[1]-1], trainPredict1[:,dataset.shape[1]-1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
AUC = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="AUC = {:.3f}".format(AUC))
plt.title("TRAINING ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
print('AUCは')
print(auc(fpr, tpr))
print('です。')
print('最適な閾値は')
opt_thr = thresholds[numpy.argmax(tpr - fpr)]
print(opt_thr)
print('です。')
plt.plot(trainPredict1[:,dataset.shape[1]-1] > opt_thr, label="prediction")
plt.plot(trainY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("training session in Optimal threshold")
plt.legend()
plt.show()
# Out:
# AUCは
# 0.9834055244068219
# です。
# 最適な閾値は
# 0.5134562253952026
# です。

# %%
y_test, y_pred = validY1[:,dataset.shape[1]-1], validPredict1[:,dataset.shape[1]-1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
AUC = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="AUC = {:.3f}".format(AUC))
plt.title("VALID ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
print('AUCは')
print(auc(fpr, tpr))
print('です。')
print('最適な閾値は')
opt_thr = thresholds[numpy.argmax(tpr - fpr)]
print(opt_thr)
print('です。')
plt.plot(testPredict1[:,dataset.shape[1]-1] > opt_thr, label="prediction")
plt.plot(testY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("valid session in Optimal threshold")
plt.legend()
plt.show()
# Out:
# AUCは
# 0.9727779542955598
# です。
# 最適な閾値は
# 0.6427235007286072
# です。

# %%
y_test, y_pred = testY1[:,dataset.shape[1]-1], testPredict1[:,dataset.shape[1]-1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
AUC = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="AUC = {:.3f}".format(AUC))
plt.title("TEST ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
print('AUCは')
print(auc(fpr, tpr))
print('です。')
print('最適な閾値は')
opt_thr = thresholds[numpy.argmax(tpr - fpr)]
print(opt_thr)
print('です。')
plt.plot(testPredict1[:,dataset.shape[1]-1] > opt_thr, label="prediction")
plt.plot(testY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("test session in Optimal threshold")
plt.legend()
plt.show()
# Out:
# AUCは
# 0.9577167878948889
# です。
# 最適な閾値は
# 0.7208652496337891
# です。

# %% [markdown]
# # shapによる判断根拠の可視化
#
# 可視化は1サンプルごとに結果が出るため、それを合計した。
# 全てのサンプルでの可視化には時間がかかるため、ランダムに200個選んで行った。

# %%
import shap
# model = load_model('best_mmodel.h5')
numpy.random.seed(seed=1)
num_tr = 200
train_idx = numpy.random.choice(range(input_train.shape[0]),num_tr)
num_te = 200
test_idx = numpy.random.choice(range(input_test.shape[0]),num_te)
print(train_idx)
print(test_idx )
explainer = shap.DeepExplainer(model, input_train[train_idx])
shap_value = explainer.shap_values(input_test[test_idx])
# Out:
# [128037 491755 470924 491263 371403  73349 117583  21440 229520 413825
#  436973 293372 167302 513300  21758 176485 575956 457611 401660 365212
#  188317 246322 294103 412649 148209  26103 444256 296022  99335 117565
#  369977 128896 323900 194769 357640  58072 432755 506312 205895  99782
#  540565 176643 338712 369137 130091 478234  28114 393231 510148 384738
#  523929   1046 214142 454013 342949 545081 535123 486566 206112 438026
#  507159    243 220462 250784 169688   5271 275825 501507 314240 447741
#   33229 315861  63052  69595 555157 295627 350471  71757 101064 499020
#  197675  78356 406375 304903  78788 470768 342226 404490  22807  81788
#  190343  91850 212444 371104 441537 483934 478546 267123 488289 264322
#  370396 113255 440162 368310  87904 254279 475111 390710 146309 420010
#   88694 249741 395249 377441 296788 461834 237973  36071  56416 270291
#  382449 264333 175316 353067 394957 310159 425097 270786  14535 449861
#  313764 377701 191784 503885 362715  54575 296397 376232 562410  15917
#  283075 486722 397725  28735 410443 275381 457181  70704 220448 336125
#  377500 378143 443420  78046  23882 508013 310304 530004 506829 422450
#  475727 115520 450156 562387 551822 161267 502426 258134 172423 211683
#  436668 413427 504098  53348 355044 288544 530323 228120 306899  92389
#  570031  72935 550991 523839  16241 378666 389834 157410  61086 318272
#  186574 115879 349852 374566 338601 170442 300697 412902 559344  78896]
# [262834 243030 198135  51984 195859  14089   4720 234547 185199 135492
#    3605 200060 152707 227768 179408 179151 121415 125454  53965  82063
#  123506 268189 230956 145883 138572  24474 247756  23495 123517 201586
#   74534 173659  58181  18603 161178 209592 191429 138825 103732  66137
#  182315  43346 189022 171860 205342 146279  33856 122676 177795 155718
#   84198 177235 263344  82237  52388 130327  40570 184569 138591 254517
#  166793 285353 157113 215798 176490  16489 118820 121968   5278  97395
#  153812 126377 275202 123093 176749  86864  19227 104776 104988 145026
#  231139 235917 177577  93476  72420 160936 254271  68083 105832 211161
#  185319  53360  97378 192206 222890   4890 247354 202716 232997 285673
#  280331  75872 134798 248011 143267    379  68128 286318 203441 169850
#   20118  87137 159174 239268 215835  42482 135902  44409  66354  49966
#   16903 161237 258320  99997 155643 222202 124686  13719 252354 230108
#  156352   2791 236572 276457 147281  60037 196650  91734 190265 164152
#  236110 221015 139258 230097 138952   6645 277267 221517 169220   2994
#  101188  42627 165562  60940  58767  86522 278346  61371 118405 270480
#  165727  13920 277931  69356  76063 107820  92952 157700 133671 174802
#  254330 110714  48638 233221 235002 108763 137717 168133 195077 235527
#  148942  90985 131246 148489  29507 234435 264127 271587 271952 238245
#   38309  33170 235854  71015 123334 216028  87092 252298 223022  90175]

# %%
shap_val = numpy.array(shap_value)
shap_val.shape
# Out:
# (1, 200, 10, 50)

# %%
s = numpy.sum(numpy.abs(shap_val),axis=1).reshape([10,50])
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15.0, 10.0))
sns.heatmap(s.transpose(),cmap='viridis', annot=True)
plt.xticks( numpy.arange(0.5,10.5), numpy.arange(-10,0))
plt.yticks( numpy.arange(0.5,50.5), numpy.arange(1,51))
plt.show()
