# %%
import os
import tensorflow as tf
import logging
import warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.utils import np_utils
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense
from keras.layers import LSTM, GRU, SimpleRNN, ConvLSTM2D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from scipy import io
# Out:
# Using TensorFlow backend.

# %%
set_num = 64
matdata = io.loadmat('data/signals.mat')
signals = numpy.zeros((50, 18000*set_num))
for i in range(set_num):
    signals[:,i*18000:(i+1)*18000]  = matdata['s'+str(i+1)]
plt.plot(signals.transpose())
plt.show()
print(signals.shape)
# Out:
# (50, 1152000)

# %%
matdata = io.loadmat('data/behaviors.mat')
behavis = numpy.zeros((1, 18000*set_num))
for i in range(set_num):
    behavis[:,i*18000:(i+1)*18000]  = matdata['b'+str(i+1)]
plt.plot(behavis.transpose())
plt.show()
print(behavis.shape)
# Out:
# (1, 1152000)

# %%
dataset = numpy.hstack([signals.transpose().astype('float32'), behavis.transpose().astype('float32')])
print(dataset.shape)
# Out:
# (1152000, 51)

# %%
# # normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[0.5243208 , 0.4756588 , 0.52478135, ..., 0.52060586, 0.45601395,
#         1.        ],
#        [0.5294922 , 0.4874594 , 0.54577094, ..., 0.550915  , 0.44861886,
#         1.        ],
#        [0.53681123, 0.4916609 , 0.5472613 , ..., 0.5696357 , 0.44246095,
#         1.        ],
#        ...,
#        [0.38074595, 0.3246355 , 0.42398232, ..., 0.33834928, 0.34063563,
#         0.        ],
#        [0.38334918, 0.31798124, 0.40275556, ..., 0.2984794 , 0.3288611 ,
#         0.        ],
#        [0.39405167, 0.34444982, 0.4290545 , ..., 0.3360081 , 0.3545482 ,
#         0.        ]], dtype=float32)

# %%
# split into train and test sets
train_size = int(len(dataset) * 32/set_num)
valid_size = int(len(dataset) * 16/set_num)
test_size = len(dataset) - (train_size + valid_size)
train = dataset[0:train_size,:]
valid = dataset[train_size:(train_size + valid_size),:]
test = dataset[(train_size + valid_size):len(dataset),:]
print(len(train),len(valid), len(test))
# Out:
# 576000 288000 288000

# %%
# convert an array of values into a dataset matrix
def create_dataset_back(dataset, look_frame):
    dataX, dataY = [], []
    for i in range(look_frame,len(dataset)):
        xset = []
        for j in range(dataset.shape[1]-1):
            a = dataset[(i-look_frame):i, j]
            xset.append(a)
        dataY.append(dataset[i, -1])      
        dataX.append(xset)
    return numpy.array(dataX), numpy.array(dataY)

look_frame = 10 #前ｎフレームまで読み込んで入力とする
trainX, trainY = create_dataset_back(train, look_frame)
print(trainX.shape)
print(trainY.shape)
validX, validY = create_dataset_back(valid, look_frame)
print(validX.shape)
print(validY.shape)
testX, testY = create_dataset_back(test, look_frame)
print(testX.shape)
print(testY.shape)
# Out:
# (575990, 50, 10)
# (575990,)
# (287990, 50, 10)
# (287990,)
# (287990, 50, 10)
# (287990,)

# %%
# transpose input
input_train = trainX.transpose(0,2,1)
input_valid = validX.transpose(0,2,1)
input_test = testX.transpose(0,2,1)
print(input_train.shape)
print(input_valid.shape)
print(input_test.shape)
# Out:
# (575990, 10, 50)
# (287990, 10, 50)
# (287990, 10, 50)

# %%
# callback設定
modelCheckpoint = ModelCheckpoint(filepath = 'best_mmodel_mlp.h5',
                                  monitor='val_loss',
                                  verbose=1,
                                  save_best_only=True,
                                  save_weights_only=False,
                                  mode='min',
                                  period=1)

# %%
# create and fit thenetwork
from keras.layers import Flatten
model = Sequential()
model.add(Flatten(input_shape = [look_frame,trainX.shape[1]]))
model.add(Dense(24, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x=input_train, y=trainY, validation_data=(input_valid, validY), epochs=100, batch_size=256, verbose=1, callbacks=[modelCheckpoint])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                12024
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 12,441
# Trainable params: 12,441
# Non-trainable params: 0
# _________________________________________________________________
# Train on 575990 samples, validate on 287990 samples
# Epoch 1/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.5189 - accuracy: 0.7555 - val_loss: 0.5026 - val_accuracy: 0.7670
#
# Epoch 00001: val_loss improved from inf to 0.50262, saving model to best_mmodel_mlp.h5
# Epoch 2/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4685 - accuracy: 0.7869 - val_loss: 0.4761 - val_accuracy: 0.7848
#
# Epoch 00002: val_loss improved from 0.50262 to 0.47614, saving model to best_mmodel_mlp.h5
# Epoch 3/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4495 - accuracy: 0.7963 - val_loss: 0.4514 - val_accuracy: 0.7943
#
# Epoch 00003: val_loss improved from 0.47614 to 0.45136, saving model to best_mmodel_mlp.h5
# Epoch 4/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4389 - accuracy: 0.8027 - val_loss: 0.4455 - val_accuracy: 0.7980
#
# Epoch 00004: val_loss improved from 0.45136 to 0.44548, saving model to best_mmodel_mlp.h5
# Epoch 5/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4293 - accuracy: 0.8076 - val_loss: 0.4332 - val_accuracy: 0.8016
#
# Epoch 00005: val_loss improved from 0.44548 to 0.43315, saving model to best_mmodel_mlp.h5
# Epoch 6/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4206 - accuracy: 0.8125 - val_loss: 0.4309 - val_accuracy: 0.8040
#
# Epoch 00006: val_loss improved from 0.43315 to 0.43090, saving model to best_mmodel_mlp.h5
# Epoch 7/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4105 - accuracy: 0.8184 - val_loss: 0.4192 - val_accuracy: 0.8117
#
# Epoch 00007: val_loss improved from 0.43090 to 0.41923, saving model to best_mmodel_mlp.h5
# Epoch 8/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.4025 - accuracy: 0.8233 - val_loss: 0.4517 - val_accuracy: 0.7995
#
# Epoch 00008: val_loss did not improve from 0.41923
# Epoch 9/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3939 - accuracy: 0.8284 - val_loss: 0.4167 - val_accuracy: 0.8166
#
# Epoch 00009: val_loss improved from 0.41923 to 0.41665, saving model to best_mmodel_mlp.h5
# Epoch 10/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3868 - accuracy: 0.8332 - val_loss: 0.4276 - val_accuracy: 0.8151
#
# Epoch 00010: val_loss did not improve from 0.41665
# Epoch 11/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3832 - accuracy: 0.8354 - val_loss: 0.4205 - val_accuracy: 0.8186
#
# Epoch 00011: val_loss did not improve from 0.41665
# Epoch 12/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3785 - accuracy: 0.8379 - val_loss: 0.4098 - val_accuracy: 0.8227
#
# Epoch 00012: val_loss improved from 0.41665 to 0.40979, saving model to best_mmodel_mlp.h5
# Epoch 13/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3758 - accuracy: 0.8390 - val_loss: 0.4146 - val_accuracy: 0.8215
#
# Epoch 00013: val_loss did not improve from 0.40979
# Epoch 14/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3721 - accuracy: 0.8414 - val_loss: 0.4489 - val_accuracy: 0.7990
#
# Epoch 00014: val_loss did not improve from 0.40979
# Epoch 15/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3695 - accuracy: 0.8420 - val_loss: 0.4462 - val_accuracy: 0.8059
#
# Epoch 00015: val_loss did not improve from 0.40979
# Epoch 16/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3661 - accuracy: 0.8444 - val_loss: 0.4132 - val_accuracy: 0.8218
#
# Epoch 00016: val_loss did not improve from 0.40979
# Epoch 17/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3639 - accuracy: 0.8452 - val_loss: 0.4221 - val_accuracy: 0.8178
#
# Epoch 00017: val_loss did not improve from 0.40979
# Epoch 18/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3619 - accuracy: 0.8463 - val_loss: 0.4371 - val_accuracy: 0.8095
#
# Epoch 00018: val_loss did not improve from 0.40979
# Epoch 19/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3593 - accuracy: 0.8478 - val_loss: 0.4166 - val_accuracy: 0.8191
#
# Epoch 00019: val_loss did not improve from 0.40979
# Epoch 20/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3583 - accuracy: 0.8478 - val_loss: 0.4007 - val_accuracy: 0.8244
#
# Epoch 00020: val_loss improved from 0.40979 to 0.40067, saving model to best_mmodel_mlp.h5
# Epoch 21/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3563 - accuracy: 0.8491 - val_loss: 0.4199 - val_accuracy: 0.8185
#
# Epoch 00021: val_loss did not improve from 0.40067
# Epoch 22/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3548 - accuracy: 0.8496 - val_loss: 0.4091 - val_accuracy: 0.8225
#
# Epoch 00022: val_loss did not improve from 0.40067
# Epoch 23/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3508 - accuracy: 0.8515 - val_loss: 0.4140 - val_accuracy: 0.8202
#
# Epoch 00023: val_loss did not improve from 0.40067
# Epoch 24/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3518 - accuracy: 0.8512 - val_loss: 0.4738 - val_accuracy: 0.7827
#
# Epoch 00024: val_loss did not improve from 0.40067
# Epoch 25/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3474 - accuracy: 0.8538 - val_loss: 0.4237 - val_accuracy: 0.8165
#
# Epoch 00025: val_loss did not improve from 0.40067
# Epoch 26/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3466 - accuracy: 0.8538 - val_loss: 0.4276 - val_accuracy: 0.8116
#
# Epoch 00026: val_loss did not improve from 0.40067
# Epoch 27/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3444 - accuracy: 0.8552 - val_loss: 0.3906 - val_accuracy: 0.8330
#
# Epoch 00027: val_loss improved from 0.40067 to 0.39055, saving model to best_mmodel_mlp.h5
# Epoch 28/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3408 - accuracy: 0.8567 - val_loss: 0.4390 - val_accuracy: 0.8077
#
# Epoch 00028: val_loss did not improve from 0.39055
# Epoch 29/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3416 - accuracy: 0.8564 - val_loss: 0.3959 - val_accuracy: 0.8274
#
# Epoch 00029: val_loss did not improve from 0.39055
# Epoch 30/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3387 - accuracy: 0.8579 - val_loss: 0.3905 - val_accuracy: 0.8309
#
# Epoch 00030: val_loss improved from 0.39055 to 0.39049, saving model to best_mmodel_mlp.h5
# Epoch 31/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3373 - accuracy: 0.8584 - val_loss: 0.3907 - val_accuracy: 0.8325
#
# Epoch 00031: val_loss did not improve from 0.39049
# Epoch 32/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3360 - accuracy: 0.8594 - val_loss: 0.3938 - val_accuracy: 0.8308
#
# Epoch 00032: val_loss did not improve from 0.39049
# Epoch 33/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3337 - accuracy: 0.8603 - val_loss: 0.3826 - val_accuracy: 0.8356
#
# Epoch 00033: val_loss improved from 0.39049 to 0.38259, saving model to best_mmodel_mlp.h5
# Epoch 34/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3332 - accuracy: 0.8607 - val_loss: 0.3936 - val_accuracy: 0.8299
#
# Epoch 00034: val_loss did not improve from 0.38259
# Epoch 35/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3319 - accuracy: 0.8613 - val_loss: 0.3843 - val_accuracy: 0.8344
#
# Epoch 00035: val_loss did not improve from 0.38259
# Epoch 36/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3297 - accuracy: 0.8622 - val_loss: 0.3834 - val_accuracy: 0.8329
#
# Epoch 00036: val_loss did not improve from 0.38259
# Epoch 37/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3291 - accuracy: 0.8631 - val_loss: 0.3772 - val_accuracy: 0.8367
#
# Epoch 00037: val_loss improved from 0.38259 to 0.37720, saving model to best_mmodel_mlp.h5
# Epoch 38/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3280 - accuracy: 0.8632 - val_loss: 0.3767 - val_accuracy: 0.8388
#
# Epoch 00038: val_loss improved from 0.37720 to 0.37669, saving model to best_mmodel_mlp.h5
# Epoch 39/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3254 - accuracy: 0.8646 - val_loss: 0.3953 - val_accuracy: 0.8322
#
# Epoch 00039: val_loss did not improve from 0.37669
# Epoch 40/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3249 - accuracy: 0.8649 - val_loss: 0.3694 - val_accuracy: 0.8419
#
# Epoch 00040: val_loss improved from 0.37669 to 0.36938, saving model to best_mmodel_mlp.h5
# Epoch 41/100
# 575990/575990 [==============================] - 6s 10us/step - loss: 0.3240 - accuracy: 0.8653 - val_loss: 0.3834 - val_accuracy: 0.8362
#
# Epoch 00041: val_loss did not improve from 0.36938
# Epoch 42/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3228 - accuracy: 0.8658 - val_loss: 0.3706 - val_accuracy: 0.8408
#
# Epoch 00042: val_loss did not improve from 0.36938
# Epoch 43/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3219 - accuracy: 0.8668 - val_loss: 0.3838 - val_accuracy: 0.8309
#
# Epoch 00043: val_loss did not improve from 0.36938
# Epoch 44/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3215 - accuracy: 0.8667 - val_loss: 0.3696 - val_accuracy: 0.8402
#
# Epoch 00044: val_loss did not improve from 0.36938
# Epoch 45/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3205 - accuracy: 0.8673 - val_loss: 0.3651 - val_accuracy: 0.8430
#
# Epoch 00045: val_loss improved from 0.36938 to 0.36510, saving model to best_mmodel_mlp.h5
# Epoch 46/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3195 - accuracy: 0.8678 - val_loss: 0.3669 - val_accuracy: 0.8441
#
# Epoch 00046: val_loss did not improve from 0.36510
# Epoch 47/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3178 - accuracy: 0.8687 - val_loss: 0.3829 - val_accuracy: 0.8318
#
# Epoch 00047: val_loss did not improve from 0.36510
# Epoch 48/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3170 - accuracy: 0.8689 - val_loss: 0.3681 - val_accuracy: 0.8420
#
# Epoch 00048: val_loss did not improve from 0.36510
# Epoch 49/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3146 - accuracy: 0.8703 - val_loss: 0.3737 - val_accuracy: 0.8411
#
# Epoch 00049: val_loss did not improve from 0.36510
# Epoch 50/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3151 - accuracy: 0.8696 - val_loss: 0.4056 - val_accuracy: 0.8263
#
# Epoch 00050: val_loss did not improve from 0.36510
# Epoch 51/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3141 - accuracy: 0.8705 - val_loss: 0.4053 - val_accuracy: 0.8243
#
# Epoch 00051: val_loss did not improve from 0.36510
# Epoch 52/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3130 - accuracy: 0.8713 - val_loss: 0.4055 - val_accuracy: 0.8209
#
# Epoch 00052: val_loss did not improve from 0.36510
# Epoch 53/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3125 - accuracy: 0.8711 - val_loss: 0.3852 - val_accuracy: 0.8372
#
# Epoch 00053: val_loss did not improve from 0.36510
# Epoch 54/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3112 - accuracy: 0.8718 - val_loss: 0.3688 - val_accuracy: 0.8425
#
# Epoch 00054: val_loss did not improve from 0.36510
# Epoch 55/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3115 - accuracy: 0.8714 - val_loss: 0.3589 - val_accuracy: 0.8463
#
# Epoch 00055: val_loss improved from 0.36510 to 0.35891, saving model to best_mmodel_mlp.h5
# Epoch 56/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3103 - accuracy: 0.8724 - val_loss: 0.3701 - val_accuracy: 0.8402
#
# Epoch 00056: val_loss did not improve from 0.35891
# Epoch 57/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3097 - accuracy: 0.8725 - val_loss: 0.3629 - val_accuracy: 0.8449
#
# Epoch 00057: val_loss did not improve from 0.35891
# Epoch 58/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3072 - accuracy: 0.8737 - val_loss: 0.3666 - val_accuracy: 0.8452
#
# Epoch 00058: val_loss did not improve from 0.35891
# Epoch 59/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3078 - accuracy: 0.8735 - val_loss: 0.3690 - val_accuracy: 0.8419
#
# Epoch 00059: val_loss did not improve from 0.35891
# Epoch 60/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3077 - accuracy: 0.8735 - val_loss: 0.3542 - val_accuracy: 0.8496
#
# Epoch 00060: val_loss improved from 0.35891 to 0.35424, saving model to best_mmodel_mlp.h5
# Epoch 61/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3063 - accuracy: 0.8738 - val_loss: 0.3680 - val_accuracy: 0.8442
#
# Epoch 00061: val_loss did not improve from 0.35424
# Epoch 62/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3068 - accuracy: 0.8737 - val_loss: 0.3546 - val_accuracy: 0.8488
#
# Epoch 00062: val_loss did not improve from 0.35424
# Epoch 63/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3049 - accuracy: 0.8752 - val_loss: 0.3520 - val_accuracy: 0.8505
#
# Epoch 00063: val_loss improved from 0.35424 to 0.35205, saving model to best_mmodel_mlp.h5
# Epoch 64/100
# 575990/575990 [==============================] - 6s 10us/step - loss: 0.3053 - accuracy: 0.8745 - val_loss: 0.3587 - val_accuracy: 0.8447
#
# Epoch 00064: val_loss did not improve from 0.35205
# Epoch 65/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3044 - accuracy: 0.8750 - val_loss: 0.3562 - val_accuracy: 0.8492
#
# Epoch 00065: val_loss did not improve from 0.35205
# Epoch 66/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.3038 - accuracy: 0.8757 - val_loss: 0.3660 - val_accuracy: 0.8423
#
# Epoch 00066: val_loss did not improve from 0.35205
# Epoch 67/100
# 575990/575990 [==============================] - 5s 10us/step - loss: 0.3041 - accuracy: 0.8754 - val_loss: 0.3602 - val_accuracy: 0.8471
#
# Epoch 00067: val_loss did not improve from 0.35205
# Epoch 68/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3020 - accuracy: 0.8763 - val_loss: 0.3677 - val_accuracy: 0.8448
#
# Epoch 00068: val_loss did not improve from 0.35205
# Epoch 69/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3008 - accuracy: 0.8767 - val_loss: 0.3575 - val_accuracy: 0.8485
#
# Epoch 00069: val_loss did not improve from 0.35205
# Epoch 70/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3001 - accuracy: 0.8768 - val_loss: 0.3470 - val_accuracy: 0.8526
#
# Epoch 00070: val_loss improved from 0.35205 to 0.34696, saving model to best_mmodel_mlp.h5
# Epoch 71/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2997 - accuracy: 0.8775 - val_loss: 0.3539 - val_accuracy: 0.8499
#
# Epoch 00071: val_loss did not improve from 0.34696
# Epoch 72/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.3000 - accuracy: 0.8770 - val_loss: 0.3752 - val_accuracy: 0.8385
#
# Epoch 00072: val_loss did not improve from 0.34696
# Epoch 73/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2984 - accuracy: 0.8781 - val_loss: 0.3652 - val_accuracy: 0.8454
#
# Epoch 00073: val_loss did not improve from 0.34696
# Epoch 74/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2976 - accuracy: 0.8782 - val_loss: 0.3594 - val_accuracy: 0.8494
#
# Epoch 00074: val_loss did not improve from 0.34696
# Epoch 75/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2968 - accuracy: 0.8789 - val_loss: 0.3505 - val_accuracy: 0.8530
#
# Epoch 00075: val_loss did not improve from 0.34696
# Epoch 76/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2972 - accuracy: 0.8785 - val_loss: 0.3512 - val_accuracy: 0.8535
#
# Epoch 00076: val_loss did not improve from 0.34696
# Epoch 77/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2962 - accuracy: 0.8792 - val_loss: 0.3604 - val_accuracy: 0.8480
#
# Epoch 00077: val_loss did not improve from 0.34696
# Epoch 78/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2964 - accuracy: 0.8789 - val_loss: 0.3444 - val_accuracy: 0.8545
#
# Epoch 00078: val_loss improved from 0.34696 to 0.34445, saving model to best_mmodel_mlp.h5
# Epoch 79/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2950 - accuracy: 0.8794 - val_loss: 0.3515 - val_accuracy: 0.8516
#
# Epoch 00079: val_loss did not improve from 0.34445
# Epoch 80/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2957 - accuracy: 0.8798 - val_loss: 0.3542 - val_accuracy: 0.8499
#
# Epoch 00080: val_loss did not improve from 0.34445
# Epoch 81/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2950 - accuracy: 0.8795 - val_loss: 0.3660 - val_accuracy: 0.8469
#
# Epoch 00081: val_loss did not improve from 0.34445
# Epoch 82/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2945 - accuracy: 0.8797 - val_loss: 0.3587 - val_accuracy: 0.8472
#
# Epoch 00082: val_loss did not improve from 0.34445
# Epoch 83/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2946 - accuracy: 0.8796 - val_loss: 0.3510 - val_accuracy: 0.8525
#
# Epoch 00083: val_loss did not improve from 0.34445
# Epoch 84/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2935 - accuracy: 0.8806 - val_loss: 0.3491 - val_accuracy: 0.8531
#
# Epoch 00084: val_loss did not improve from 0.34445
# Epoch 85/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2927 - accuracy: 0.8808 - val_loss: 0.3459 - val_accuracy: 0.8544
#
# Epoch 00085: val_loss did not improve from 0.34445
# Epoch 86/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2926 - accuracy: 0.8806 - val_loss: 0.3491 - val_accuracy: 0.8531
#
# Epoch 00086: val_loss did not improve from 0.34445
# Epoch 87/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2923 - accuracy: 0.8807 - val_loss: 0.4275 - val_accuracy: 0.8191
#
# Epoch 00087: val_loss did not improve from 0.34445
# Epoch 88/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2920 - accuracy: 0.8813 - val_loss: 0.3559 - val_accuracy: 0.8521
#
# Epoch 00088: val_loss did not improve from 0.34445
# Epoch 89/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2920 - accuracy: 0.8814 - val_loss: 0.3537 - val_accuracy: 0.8529
#
# Epoch 00089: val_loss did not improve from 0.34445
# Epoch 90/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2912 - accuracy: 0.8813 - val_loss: 0.3403 - val_accuracy: 0.8575
#
# Epoch 00090: val_loss improved from 0.34445 to 0.34031, saving model to best_mmodel_mlp.h5
# Epoch 91/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2922 - accuracy: 0.8807 - val_loss: 0.3418 - val_accuracy: 0.8555
#
# Epoch 00091: val_loss did not improve from 0.34031
# Epoch 92/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2909 - accuracy: 0.8816 - val_loss: 0.3530 - val_accuracy: 0.8507
#
# Epoch 00092: val_loss did not improve from 0.34031
# Epoch 93/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2900 - accuracy: 0.8821 - val_loss: 0.3426 - val_accuracy: 0.8564
#
# Epoch 00093: val_loss did not improve from 0.34031
# Epoch 94/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2904 - accuracy: 0.8817 - val_loss: 0.3402 - val_accuracy: 0.8577
#
# Epoch 00094: val_loss improved from 0.34031 to 0.34016, saving model to best_mmodel_mlp.h5
# Epoch 95/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2913 - accuracy: 0.8811 - val_loss: 0.3848 - val_accuracy: 0.8365
#
# Epoch 00095: val_loss did not improve from 0.34016
# Epoch 96/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2914 - accuracy: 0.8812 - val_loss: 0.3522 - val_accuracy: 0.8522
#
# Epoch 00096: val_loss did not improve from 0.34016
# Epoch 97/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2907 - accuracy: 0.8816 - val_loss: 0.3616 - val_accuracy: 0.8452
#
# Epoch 00097: val_loss did not improve from 0.34016
# Epoch 98/100
# 575990/575990 [==============================] - 5s 9us/step - loss: 0.2897 - accuracy: 0.8820 - val_loss: 0.3879 - val_accuracy: 0.8336
#
# Epoch 00098: val_loss did not improve from 0.34016
# Epoch 99/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2885 - accuracy: 0.8825 - val_loss: 0.3511 - val_accuracy: 0.8525
#
# Epoch 00099: val_loss did not improve from 0.34016
# Epoch 100/100
# 575990/575990 [==============================] - 5s 8us/step - loss: 0.2895 - accuracy: 0.8823 - val_loss: 0.3767 - val_accuracy: 0.8392
#
# Epoch 00100: val_loss did not improve from 0.34016

# %%
# plot
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %%
# Predict
model = load_model('best_mmodel_mlp.h5')
trainPredict = model.predict(input_train)
validPredict = model.predict(input_valid)
testPredict = model.predict(input_test)

# %%
# make predictions
pad_col = numpy.zeros(dataset.shape[1]-1)
def pad_array(val):
    return numpy.array([numpy.insert(pad_col, dataset.shape[1]-1, x) for x in val])

trainPredict1 = scaler.inverse_transform(pad_array(trainPredict))
trainY1 = scaler.inverse_transform(pad_array(trainY))

validPredict1 = scaler.inverse_transform(pad_array(validPredict))
validY1 = scaler.inverse_transform(pad_array(validY))

testPredict1 = scaler.inverse_transform(pad_array(testPredict))
testY1 = scaler.inverse_transform(pad_array(testY))

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY1[:,dataset.shape[1]-1], trainPredict1[:,dataset.shape[1]-1]))
print('Train Score: %.2f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY1[:,dataset.shape[1]-1], validPredict1[:,dataset.shape[1]-1]))
print('Valid Score: %.2f RMSE' % (validScore))
testScore = math.sqrt(mean_squared_error(testY1[:,dataset.shape[1]-1], testPredict1[:,dataset.shape[1]-1]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.29 RMSE
# Valid Score: 0.32 RMSE
# Test Score: 0.35 RMSE

# %%
# plot baseline and predictions
plt.plot(trainPredict1[:,dataset.shape[1]-1], label="prediction")
plt.plot(trainY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("training session")
plt.legend()
plt.show()
plt.plot(validPredict1[:,dataset.shape[1]-1], label="prediction")
plt.plot(validY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("valid session")
plt.legend()
plt.show()
plt.plot(testPredict1[:,dataset.shape[1]-1], label="prediction")
plt.plot(testY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("test session")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10.0, 5.0))
plt.plot(testPredict1[:,dataset.shape[1]-1])
plt.title("test prediction")
plt.show()
plt.figure(figsize=(10.0, 5.0))
plt.plot(testY1[:,dataset.shape[1]-1])
plt.title("test ground truth")
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc, roc_auc_score

y_test, y_pred = trainY1[:,dataset.shape[1]-1], trainPredict1[:,dataset.shape[1]-1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
AUC = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="AUC = {:.3f}".format(AUC))
plt.title("TRAINING ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
print('AUCは')
print(auc(fpr, tpr))
print('です。')
print('最適な閾値は')
opt_thr = thresholds[numpy.argmax(tpr - fpr)]
print(opt_thr)
print('です。')
plt.plot(trainPredict1[:,dataset.shape[1]-1] > opt_thr, label="prediction")
plt.plot(trainY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("training session in Optimal threshold")
plt.legend()
plt.show()
# Out:
# AUCは
# 0.9472678504992558
# です。
# 最適な閾値は
# 0.5766820311546326
# です。

# %%
y_test, y_pred = validY1[:,dataset.shape[1]-1], validPredict1[:,dataset.shape[1]-1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
AUC = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="AUC = {:.3f}".format(AUC))
plt.title("VALID ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
print('AUCは')
print(auc(fpr, tpr))
print('です。')
print('最適な閾値は')
opt_thr = thresholds[numpy.argmax(tpr - fpr)]
print(opt_thr)
print('です。')
plt.plot(testPredict1[:,dataset.shape[1]-1] > opt_thr, label="prediction")
plt.plot(testY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("valid session in Optimal threshold")
plt.legend()
plt.show()
# Out:
# AUCは
# 0.9191039816004374
# です。
# 最適な閾値は
# 0.633446216583252
# です。

# %%
y_test, y_pred = testY1[:,dataset.shape[1]-1], testPredict1[:,dataset.shape[1]-1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=1)
AUC = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="AUC = {:.3f}".format(AUC))
plt.title("TEST ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
print('AUCは')
print(auc(fpr, tpr))
print('です。')
print('最適な閾値は')
opt_thr = thresholds[numpy.argmax(tpr - fpr)]
print(opt_thr)
print('です。')
plt.plot(testPredict1[:,dataset.shape[1]-1] > opt_thr, label="prediction")
plt.plot(testY1[:,dataset.shape[1]-1], label="grand truth")
plt.title("test session in Optimal threshold")
plt.legend()
plt.show()
# Out:
# AUCは
# 0.8963201317761263
# です。
# 最適な閾値は
# 0.5389457941055298
# です。

# %% [markdown]
# # shapによる判断根拠の可視化
#
# 可視化は1サンプルごとに結果が出るため、それを合計した。
# 全てのサンプルでの可視化には時間がかかるため、ランダムに200個選んで行った。

# %%
import shap
# model = load_model('best_mmodel_mlp.h5')
numpy.random.seed(seed=1)
num_tr = 200
train_idx = numpy.random.choice(range(input_train.shape[0]),num_tr)
num_te = 200
test_idx = numpy.random.choice(range(input_test.shape[0]),num_te)
print(train_idx)
print(test_idx )
explainer = shap.DeepExplainer(model, input_train[train_idx])
shap_value = explainer.shap_values(input_test[test_idx])
# Out:
# [128037 491755 470924 491263 371403  73349 117583  21440 229520 413825
#  436973 293372 167302 513300  21758 176485 575956 457611 401660 365212
#  188317 246322 294103 412649 148209  26103 444256 296022  99335 117565
#  369977 128896 323900 194769 357640  58072 432755 506312 205895  99782
#  540565 176643 338712 369137 130091 478234  28114 393231 510148 384738
#  523929   1046 214142 454013 342949 545081 535123 486566 206112 438026
#  507159    243 220462 250784 169688   5271 275825 501507 314240 447741
#   33229 315861  63052  69595 555157 295627 350471  71757 101064 499020
#  197675  78356 406375 304903  78788 470768 342226 404490  22807  81788
#  190343  91850 212444 371104 441537 483934 478546 267123 488289 264322
#  370396 113255 440162 368310  87904 254279 475111 390710 146309 420010
#   88694 249741 395249 377441 296788 461834 237973  36071  56416 270291
#  382449 264333 175316 353067 394957 310159 425097 270786  14535 449861
#  313764 377701 191784 503885 362715  54575 296397 376232 562410  15917
#  283075 486722 397725  28735 410443 275381 457181  70704 220448 336125
#  377500 378143 443420  78046  23882 508013 310304 530004 506829 422450
#  475727 115520 450156 562387 551822 161267 502426 258134 172423 211683
#  436668 413427 504098  53348 355044 288544 530323 228120 306899  92389
#  570031  72935 550991 523839  16241 378666 389834 157410  61086 318272
#  186574 115879 349852 374566 338601 170442 300697 412902 559344  78896]
# [262834 243030 198135  51984 195859  14089   4720 234547 185199 135492
#    3605 200060 152707 227768 179408 179151 121415 125454  53965  82063
#  123506 268189 230956 145883 138572  24474 247756  23495 123517 201586
#   74534 173659  58181  18603 161178 209592 191429 138825 103732  66137
#  182315  43346 189022 171860 205342 146279  33856 122676 177795 155718
#   84198 177235 263344  82237  52388 130327  40570 184569 138591 254517
#  166793 285353 157113 215798 176490  16489 118820 121968   5278  97395
#  153812 126377 275202 123093 176749  86864  19227 104776 104988 145026
#  231139 235917 177577  93476  72420 160936 254271  68083 105832 211161
#  185319  53360  97378 192206 222890   4890 247354 202716 232997 285673
#  280331  75872 134798 248011 143267    379  68128 286318 203441 169850
#   20118  87137 159174 239268 215835  42482 135902  44409  66354  49966
#   16903 161237 258320  99997 155643 222202 124686  13719 252354 230108
#  156352   2791 236572 276457 147281  60037 196650  91734 190265 164152
#  236110 221015 139258 230097 138952   6645 277267 221517 169220   2994
#  101188  42627 165562  60940  58767  86522 278346  61371 118405 270480
#  165727  13920 277931  69356  76063 107820  92952 157700 133671 174802
#  254330 110714  48638 233221 235002 108763 137717 168133 195077 235527
#  148942  90985 131246 148489  29507 234435 264127 271587 271952 238245
#   38309  33170 235854  71015 123334 216028  87092 252298 223022  90175]

# %%
shap_val = numpy.array(shap_value)
shap_val.shape
# Out:
# (1, 200, 10, 50)

# %%
s = numpy.sum(numpy.abs(shap_val),axis=1).reshape([10,50])
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15.0, 10.0))
sns.heatmap(s.transpose(),cmap='viridis', annot=True)
plt.xticks( numpy.arange(0.5,10.5), numpy.arange(-10,0))
plt.yticks( numpy.arange(0.5,50.5), numpy.arange(1,51))
plt.show()
